# %%
# %reload_ext autoreload
# %autoreload

# %%
import sys
sys.path.append('/home/anand/Projects/climpy/src/')

# %%
import pandas as pd
import xarray as xr
import numpy as np

from climpy.transform.condition import ThresholdQuantile

# %%
from tests.utils import test_xarray_areal_small

# %%
data = test_xarray_areal_small()

# %%
np.percentile(data, q = 90, axis=2)
# Out:
# array([[89.1, 89.1, 89.1, ..., 89.1, 89.1, 89.1],
#        [89.1, 89.1, 89.1, ..., 89.1, 89.1, 89.1],
#        [89.1, 89.1, 89.1, ..., 89.1, 89.1, 89.1],
#        ...,
#        [89.1, 89.1, 89.1, ..., 89.1, 89.1, 89.1],
#        [89.1, 89.1, 89.1, ..., 89.1, 89.1, 89.1],
#        [89.1, 89.1, 89.1, ..., 89.1, 89.1, 89.1]])

# %%
data
# Out:
# <xarray.DataArray (lon: 64, lat: 32, time: 100)>
# array([[[ 0,  1,  2, ..., 97, 98, 99],
#         [ 0,  1,  2, ..., 97, 98, 99],
#         [ 0,  1,  2, ..., 97, 98, 99],
#         ...,
#         [ 0,  1,  2, ..., 97, 98, 99],
#         [ 0,  1,  2, ..., 97, 98, 99],
#         [ 0,  1,  2, ..., 97, 98, 99]],
#
#        [[ 0,  1,  2, ..., 97, 98, 99],
#         [ 0,  1,  2, ..., 97, 98, 99],
#         [ 0,  1,  2, ..., 97, 98, 99],
#         ...,
#         [ 0,  1,  2, ..., 97, 98, 99],
#         [ 0,  1,  2, ..., 97, 98, 99],
#         [ 0,  1,  2, ..., 97, 98, 99]],
#
#        [[ 0,  1,  2, ..., 97, 98, 99],
#         [ 0,  1,  2, ..., 97, 98, 99],
#         [ 0,  1,  2, ..., 97, 98, 99],
#         ...,
# ...
#         ...,
#         [ 0,  1,  2, ..., 97, 98, 99],
#         [ 0,  1,  2, ..., 97, 98, 99],
#         [ 0,  1,  2, ..., 97, 98, 99]],
#
#        [[ 0,  1,  2, ..., 97, 98, 99],
#         [ 0,  1,  2, ..., 97, 98, 99],
#         [ 0,  1,  2, ..., 97, 98, 99],
# ...

# %%
np.percentile([1,2,2], 90)
# Out:
# 2.0
